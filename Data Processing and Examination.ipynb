# %% [markdown]
# # Fetch Rewards Coding Exercise - Data Analyst

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Receipts Dataframe Cleaning

# %%
receipts = pd.read_json('receipts.json', lines = True)

# %%
receipts.shape
# Out:
# (1119, 15)

# %%
# take a glance of the data
receipts.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# 4  {'$date': 1609687506000}  {'$date': 1609687506000}
#
#                finishedDate                modifyDate  \
# 0  {'$date': 1609687531000}  {'$date': 1609687536000}
# 1  {'$date': 1609687483000}  {'$date': 1609687488000}
# 2                       NaN  {'$date': 1609687542000}
# 3  {'$date': 1609687534000}  {'$date': 1609687539000}
# 4  {'$date': 1609687511000}  {'$date': 1609687511000}
#
#           pointsAwardedDate  pointsEarned              purchaseDate  \
# 0  {'$date': 1609687531000}         500.0  {'$date': 1609632000000}
# 1  {'$date': 1609687483000}         150.0  {'$date': 1609601083000}
# 2                       NaN           5.0  {'$date': 1609632000000}
# 3  {'$date': 1609687534000}           5.0  {'$date': 1609632000000}
# 4  {'$date': 1609687506000}           5.0  {'$date': 1609601106000}
#
#    purchasedItemCount                             rewardsReceiptItemList  \
# 0                 5.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 1                 2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 2                 1.0  [{'needsFetchReview': False, 'partnerItemId': ...
# 3                 4.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 4                 2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
#
#   rewardsReceiptStatus  totalSpent                    userId
# 0             FINISHED        26.0  5ff1e1eacfcf6c399c274ae6
# 1             FINISHED        11.0  5ff1e194b6a9d73a3a9f1052
# 2             REJECTED        10.0  5ff1e1f1cfcf6c399c274b0b
# 3             FINISHED        28.0  5ff1e1eacfcf6c399c274ae6
# 4             FINISHED         1.0  5ff1e194b6a9d73a3a9f1052

# %%
receipts['rewardsReceiptItemList'].describe()
# Out:
# count                                                   679
# unique                                                  383
# top       [{'description': 'flipbelt level terrain waist...
# freq                                                     50
# Name: rewardsReceiptItemList, dtype: object

# %% [markdown]
# #### There appear to be two major issues in this dataframe:
# ####    1. varables in some of the columns are not neat: the '_id' column, and the date columns - going to clean the
# ####        data and change the date data type
# ####    2. there are embeded dictionaries and lists in the column "rewardsReceiptItemList" - going to create another
# ####       dataframe to store this information and use receipt id ('_id') as the foreign key.
# ####        I didn't expand the column in the existing table because there are lots of Null value and will be too
# ####        redundent to include this column for every receipt id ('_id')

# %%
#create a function to convert the date data type
def date_convert(date):
    try:
        return (datetime.utcfromtimestamp(int(date['$date'])/1000).strftime('%Y-%m-%d %H:%M:%S'))
    except TypeError:
        return None

# %%
receipts['_id'] = receipts['_id'].apply(lambda x:x['$oid'])
receipts['createDate'] = receipts['createDate'].apply(lambda x:date_convert(x))
receipts['dateScanned'] = receipts['dateScanned'].apply(lambda x:date_convert(x))
receipts['finishedDate'] = receipts['finishedDate'].apply(lambda x:date_convert(x))
receipts['modifyDate'] = receipts['modifyDate'].apply(lambda x:date_convert(x))
receipts['pointsAwardedDate'] = receipts['pointsAwardedDate'].apply(lambda x:date_convert(x))
receipts['purchaseDate'] = receipts['purchaseDate'].apply(lambda x:date_convert(x))
receipts2 = receipts.drop(['rewardsReceiptItemList'], axis=1)
receipts_final = receipts2.fillna("Null")

# %%
receipts_final
# Out:
#                            _id bonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575               500
# 1     5ff1e1bb0a720f052300056b               150
# 2     5ff1e1f10a720f052300057a                 5
# 3     5ff1e1ee0a7214ada100056f                 5
# 4     5ff1e1d20a7214ada1000561                 5
# ...                        ...               ...
# 1114  603cc0630a720fde100003e6                25
# 1115  603d0b710a720fde1000042a              Null
# 1116  603cf5290a720fde10000413              Null
# 1117  603ce7100a7217c72c000405                25
# 1118  603c4fea0a7217c72c000389              Null
#
#                                 bonusPointsEarnedReason           createDate  \
# 0     Receipt number 2 completed, bonus point schedu...  2021-01-03 15:25:31
# 1     Receipt number 5 completed, bonus point schedu...  2021-01-03 15:24:43
# 2                            All-receipts receipt bonus  2021-01-03 15:25:37
# 3                            All-receipts receipt bonus  2021-01-03 15:25:34
# 4                            All-receipts receipt bonus  2021-01-03 15:25:06
# ...                                                 ...                  ...
# 1114                        COMPLETE_NONPARTNER_RECEIPT  2021-03-01 10:22:27
# 1115                                               Null  2021-03-01 15:42:41
# 1116                                               Null  2021-03-01 14:07:37
# 1117                        COMPLETE_NONPARTNER_RECEIPT  2021-03-01 13:07:28
# 1118                                               Null  2021-03-01 02:22:34
#
#               dateScanned         finishedDate           modifyDate  \
# 0     2021-01-03 15:25:31  2021-01-03 15:25:31  2021-01-03 15:25:36
# 1     2021-01-03 15:24:43  2021-01-03 15:24:43  2021-01-03 15:24:48
# 2     2021-01-03 15:25:37                 Null  2021-01-03 15:25:42
# 3     2021-01-03 15:25:34  2021-01-03 15:25:34  2021-01-03 15:25:39
# 4     2021-01-03 15:25:06  2021-01-03 15:25:11  2021-01-03 15:25:11
# ...                   ...                  ...                  ...
# 1114  2021-03-01 10:22:27                 Null  2021-03-01 10:22:28
# 1115  2021-03-01 15:42:41                 Null  2021-03-01 15:42:41
# 1116  2021-03-01 14:07:37                 Null  2021-03-01 14:07:37
# 1117  2021-03-01 13:07:28                 Null  2021-03-01 13:07:29
# 1118  2021-03-01 02:22:34                 Null  2021-03-01 02:22:34
#
#         pointsAwardedDate pointsEarned         purchaseDate  \
# 0     2021-01-03 15:25:31          500  2021-01-03 00:00:00
# 1     2021-01-03 15:24:43          150  2021-01-02 15:24:43
# 2                    Null            5  2021-01-03 00:00:00
# 3     2021-01-03 15:25:34            5  2021-01-03 00:00:00
# 4     2021-01-03 15:25:06            5  2021-01-02 15:25:06
# ...                   ...          ...                  ...
# 1114                 Null           25  2020-08-17 00:00:00
# 1115                 Null         Null                 Null
# 1116                 Null         Null                 Null
# 1117                 Null           25  2020-08-17 00:00:00
# 1118                 Null         Null                 Null
#
#      purchasedItemCount rewardsReceiptStatus totalSpent  \
# 0                     5             FINISHED         26
# 1                     2             FINISHED         11
# 2                     1             REJECTED         10
# 3                     4             FINISHED         28
# 4                     2             FINISHED          1
# ...                 ...                  ...        ...
# 1114                  2             REJECTED      34.96
# 1115               Null            SUBMITTED       Null
# 1116               Null            SUBMITTED       Null
# 1117                  2             REJECTED      34.96
# 1118               Null            SUBMITTED       Null
#
#                         userId
# 0     5ff1e1eacfcf6c399c274ae6
# 1     5ff1e194b6a9d73a3a9f1052
# 2     5ff1e1f1cfcf6c399c274b0b
# 3     5ff1e1eacfcf6c399c274ae6
# 4     5ff1e194b6a9d73a3a9f1052
# ...                        ...
# 1114  5fc961c3b8cfca11a077dd33
# 1115  5fc961c3b8cfca11a077dd33
# 1116  5fc961c3b8cfca11a077dd33
# 1117  5fc961c3b8cfca11a077dd33
# 1118  5fc961c3b8cfca11a077dd33
#
# [1119 rows x 14 columns]

# %%
#create a new table for 'rewardsReceiptItemList' column
rewardsReceiptItemList = receipts[['_id', 'rewardsReceiptItemList']]
rewardsReceiptItemList = rewardsReceiptItemList.explode('rewardsReceiptItemList')
rewardsReceiptItemList = rewardsReceiptItemList[rewardsReceiptItemList['rewardsReceiptItemList'].notna()]
rewardsReceiptItemList.reset_index(inplace=True)
rewardsReceiptItemList2 = pd.json_normalize(rewardsReceiptItemList['rewardsReceiptItemList'])
rewardsReceiptItemList_final1 = pd.concat([rewardsReceiptItemList.drop(['rewardsReceiptItemList'], axis=1),
                                         rewardsReceiptItemList2], axis=1)
rewardsReceiptItemList_final=rewardsReceiptItemList_final1.fillna('Null')

# %%
rewardsReceiptItemList_final
# Out:
#       index                       _id       barcode  \
# 0         0  5ff1e1eb0a720f0523000575          4011
# 1         1  5ff1e1bb0a720f052300056b          4011
# 2         1  5ff1e1bb0a720f052300056b  028400642255
# 3         2  5ff1e1f10a720f052300057a          Null
# 4         3  5ff1e1ee0a7214ada100056f          4011
# ...     ...                       ...           ...
# 6936   1113  603cc2bc0a720fde100003e9    B07BRRLSVC
# 6937   1114  603cc0630a720fde100003e6    B076FJ92M4
# 6938   1114  603cc0630a720fde100003e6    B07BRRLSVC
# 6939   1117  603ce7100a7217c72c000405    B076FJ92M4
# 6940   1117  603ce7100a7217c72c000405    B07BRRLSVC
#
#                                             description finalPrice itemPrice  \
# 0                                        ITEM NOT FOUND      26.00     26.00
# 1                                        ITEM NOT FOUND          1         1
# 2     DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00     10.00
# 3                                                  Null       Null      Null
# 4                                        ITEM NOT FOUND      28.00     28.00
# ...                                                 ...        ...       ...
# 6936  thindust summer face mask - sun protection nec...      11.99     11.99
# 6937  mueller austria hypergrind precision electric ...      22.97     22.97
# 6938  thindust summer face mask - sun protection nec...      11.99     11.99
# 6939  mueller austria hypergrind precision electric ...      22.97     22.97
# 6940  thindust summer face mask - sun protection nec...      11.99     11.99
#
#      needsFetchReview partnerItemId preventTargetGapPoints quantityPurchased  \
# 0               False             1                   True                 5
# 1                Null             1                   Null                 1
# 2                True             2                   True                 1
# 3               False             1                   True              Null
# 4               False             1                   True                 4
# ...               ...           ...                    ...               ...
# 6936             Null             1                   Null                 1
# 6937             Null             0                   Null                 1
# 6938             Null             1                   Null                 1
# 6939             Null             0                   Null                 1
# 6940             Null             1                   Null                 1
#
#       ... itemNumber originalMetaBriteQuantityPurchased pointsEarned  \
# 0     ...       Null                               Null         Null
# 1     ...       Null                               Null         Null
# 2     ...       Null                               Null         Null
# 3     ...       Null                               Null         Null
# 4     ...       Null                               Null         Null
# ...   ...        ...                                ...          ...
# 6936  ...       Null                               Null         Null
# 6937  ...       Null                               Null         Null
# 6938  ...       Null                               Null         Null
# 6939  ...       Null                               Null         Null
# 6940  ...       Null                               Null         Null
#
#      targetPrice competitiveProduct originalFinalPrice  \
# 0           Null               Null               Null
# 1           Null               Null               Null
# 2           Null               Null               Null
# 3           Null               Null               Null
# 4           Null               Null               Null
# ...          ...                ...                ...
# 6936        Null               Null               Null
# 6937        Null               Null               Null
# 6938        Null               Null               Null
# 6939        Null               Null               Null
# 6940        Null               Null               Null
#
#      originalMetaBriteItemPrice deleted priceAfterCoupon metabriteCampaignId
# 0                          Null    Null             Null                Null
# 1                          Null    Null             Null                Null
# 2                          Null    Null             Null                Null
# 3                          Null    Null             Null                Null
# 4                          Null    Null             Null                Null
# ...                         ...     ...              ...                 ...
# 6936                       Null    Null            11.99                Null
# 6937                       Null    Null            22.97                Null
# 6938                       Null    Null            11.99                Null
# 6939                       Null    Null            22.97                Null
# 6940                       Null    Null            11.99                Null
#
# [6941 rows x 36 columns]

# %% [markdown]
# ### Users Dataframe Cleaning

# %%
users = pd.read_json('users.json', lines = True)
users.shape
# Out:
# (495, 7)

# %%
users.head()
# Out:
#                                     _id  active               createdDate  \
# 0  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3  {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %% [markdown]
# #### There appear to be the same issue: the '_id' column is not clean and the date data type needs to be converted

# %%
users['_id'] = users['_id'].apply(lambda x:x['$oid'])
users['createdDate'] = users['createdDate'].apply(lambda x:date_convert(x))
users['lastLogin'] = users['lastLogin'].apply(lambda x:date_convert(x))
users_final = users.fillna('Null')
users_final
# Out:
#                           _id  active          createdDate  \
# 0    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04
# 2    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04
# 3    5ff1e1eacfcf6c399c274ae6    True  2021-01-03 15:25:30
# 4    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04
# ..                        ...     ...                  ...
# 490  54943462e4b07e684157a532    True  2014-12-19 14:21:22
# 491  54943462e4b07e684157a532    True  2014-12-19 14:21:22
# 492  54943462e4b07e684157a532    True  2014-12-19 14:21:22
# 493  54943462e4b07e684157a532    True  2014-12-19 14:21:22
# 494  54943462e4b07e684157a532    True  2014-12-19 14:21:22
#
#                lastLogin         role signUpSource state
# 0    2021-01-03 15:25:37     consumer        Email    WI
# 1    2021-01-03 15:25:37     consumer        Email    WI
# 2    2021-01-03 15:25:37     consumer        Email    WI
# 3    2021-01-03 15:25:30     consumer        Email    WI
# 4    2021-01-03 15:25:37     consumer        Email    WI
# ..                   ...          ...          ...   ...
# 490  2021-03-05 16:52:23  fetch-staff         Null  Null
# 491  2021-03-05 16:52:23  fetch-staff         Null  Null
# 492  2021-03-05 16:52:23  fetch-staff         Null  Null
# 493  2021-03-05 16:52:23  fetch-staff         Null  Null
# 494  2021-03-05 16:52:23  fetch-staff         Null  Null
#
# [495 rows x 7 columns]

# %% [markdown]
# ### Brands Dataframe Cleaning

# %%
brands = pd.read_json('brands.json', lines = True)
brands.shape
# Out:
# (1167, 8)

# %%
brands.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176
# 3  test brand @1612366146051       0.0  TEST BRANDCODE @1612366146051
# 4  test brand @1612366146827       0.0  TEST BRANDCODE @1612366146827

# %%
#take a look at the 'cpg' column
brands['cpg'][0]
# Out:
# {'$id': {'$oid': '601ac114be37ce2ead437550'}, '$ref': 'Cogs'}

# %% [markdown]
# #### The '_id' column needs to be cleaned and the 'cpg' column needs to be split into two columns

# %%
brands['_id'] = brands['_id'].apply(lambda x:x['$oid'])
brands['cpg_id'] = brands['cpg'].apply(lambda x:x['$id']['$oid'])
brands['cpg_ref'] = brands['cpg'].apply(lambda x:x['$ref'])
brands = brands.drop(['cpg'], axis=1)
brands_final = brands.fillna('Null')

# %%
brands_final
# Out:
#                            _id       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode                       name topBrand  \
# 0               BAKING  test brand @1612366101024        0
# 1            BEVERAGES                  Starbucks        0
# 2               BAKING  test brand @1612366146176        0
# 3               BAKING  test brand @1612366146051        0
# 4     CANDY_AND_SWEETS  test brand @1612366146827        0
# ...                ...                        ...      ...
# 1162            BAKING  test brand @1601644365844     Null
# 1163              Null        Dippin Dots® Cereal     Null
# 1164  CANDY_AND_SWEETS  test brand @1598639215217     Null
# 1165              Null          LIPTON TEA Leaves        0
# 1166            BAKING  test brand @1613158231643        0
#
#                           brandCode                    cpg_id cpg_ref
# 0                              Null  601ac114be37ce2ead437550    Cogs
# 1                         STARBUCKS  5332f5fbe4b03c9a25efd0ba    Cogs
# 2     TEST BRANDCODE @1612366146176  601ac142be37ce2ead437559    Cogs
# 3     TEST BRANDCODE @1612366146051  601ac142be37ce2ead437559    Cogs
# 4     TEST BRANDCODE @1612366146827  5332fa12e4b03c9a25efd1e7    Cogs
# ...                             ...                       ...     ...
# 1162                           Null  5f77274dbe37ce6b592e90bf    Cogs
# 1163             DIPPIN DOTS CEREAL  53e10d6368abd3c7065097cc    Cogs
# 1164  TEST BRANDCODE @1598639215217  5332fa12e4b03c9a25efd1e7    Cogs
# 1165              LIPTON TEA Leaves  5332f5f6e4b03c9a25efd0b4    Cogs
# 1166  TEST BRANDCODE @1613158231644  6026d757be37ce6369301467    Cogs
#
# [1167 rows x 9 columns]

# %%
#Write these four tables into csv file for SQL query
receipts_final.to_csv("receipts_final.csv", index=True, index_label="UniqueID")
rewardsReceiptItemList_final.to_csv("rewardsReceiptItemList_final.csv", index=True, index_label="UniqueID")
users_final.to_csv("users_final.csv", index=True, index_label="UniqueID")
brands_final.to_csv("brands_final.csv", index=True, index_label="UniqueID")

# %% [markdown]
# # Data Examination

# %%
# check users dataframe
users.isnull().sum()
# Out:
# _id              0
# active           0
# createdDate      0
# lastLogin       62
# role             0
# signUpSource    48
# state           56
# dtype: int64

# %%
users.shape
# Out:
# (495, 7)

# %%
users['_id'].duplicated().sum()
# Out:
# 283

# %%
len(users._id.unique())
# Out:
# 212

# %% [markdown]
# #### Quality issues in the users table: there are 283 dulicates ids out of 495 records, accounting for more than 50% of the table records;
# #### there are approxinately 10% missing values in some of the columns.

# %%
# check the brands dataframe
brands.isnull().sum()
# Out:
# _id               0
# barcode           0
# category        155
# categoryCode    650
# name              0
# topBrand        612
# brandCode       234
# cpg_id            0
# cpg_ref           0
# dtype: int64

# %%
brands.shape
# Out:
# (1167, 9)

# %%
brands['_id'].duplicated().sum()
# Out:
# 0

# %%
brands['name'].duplicated().sum()
# Out:
# 11

# %%
len(brands.name.unique())
# Out:
# 1156

# %%
brands['brandCode'].duplicated().sum()
# Out:
# 269

# %%
len(brands.brandCode.unique())
# Out:
# 898

# %% [markdown]
# #### Quality issues in the brands table: different '_id's may share the same brand name and/or barcode;
# #### the number of unique 'name' and 'barcode' doesn't match: one brandcode may have multiple brand names;
# #### there are more than 50% of missing values in some of the columns.

# %%
# check the receipts dataframe
receipts2.isnull().sum()
# Out:
# _id                          0
# bonusPointsEarned          575
# bonusPointsEarnedReason    575
# createDate                   0
# dateScanned                  0
# finishedDate               551
# modifyDate                   0
# pointsAwardedDate          582
# pointsEarned               510
# purchaseDate               448
# purchasedItemCount         484
# rewardsReceiptStatus         0
# totalSpent                 435
# userId                       0
# dtype: int64

# %%
receipts2.shape
# Out:
# (1119, 14)

# %%
receipts[receipts['purchasedItemCount']==0]
# Out:
#                           _id  bonusPointsEarned  \
# 15   5ff1e1e90a7214ada1000569                NaN
# 81   5ff4ce3c0a720f05230005c4                NaN
# 141  5ff73be90a720f052300060a                NaN
# 144  5ff794600a7214ada1000647                NaN
# 175  5ff8da570a720f05c5000015                NaN
# 179  5ff8da7d0a720f05c500001c                NaN
# 282  6000d4aa0a720f05f3000072                NaN
# 396  6009eb000a7214ada2000003              250.0
# 424  600aff160a720f053500000c              500.0
# 544  60132b890a7214ad50000013                NaN
# 559  60145a540a720f05f8000116                NaN
# 642  601830cd0a720f05f800034f                NaN
# 656  60182f390a7214ad500002b8                NaN
# 681  60189c920a7214ad2800003a                NaN
# 727  601b32160a7214ad28000221                NaN
#
#                                bonusPointsEarnedReason           createDate  \
# 15                                                 NaN  2021-01-03 15:25:29
# 81                                                 NaN  2021-01-05 20:38:20
# 141                                                NaN  2021-01-07 16:50:49
# 144                                                NaN  2021-01-07 05:08:16
# 175                                                NaN  2021-01-08 22:19:03
# 179                                                NaN  2021-01-08 22:19:41
# 282                                                NaN  2021-01-14 23:32:58
# 396  Receipt number 3 completed, bonus point schedu...  2021-01-21 20:58:40
# 424  Receipt number 2 completed, bonus point schedu...  2021-01-22 16:36:38
# 544                                                NaN  2021-01-28 21:24:25
# 559                                                NaN  2021-01-29 18:56:20
# 642                                                NaN  2021-02-01 16:48:13
# 656                                                NaN  2021-02-01 16:41:29
# 681                                                NaN  2021-02-02 00:28:02
# 727                                                NaN  2021-02-03 23:30:30
#
#              dateScanned         finishedDate           modifyDate  \
# 15   2021-01-03 15:25:29                 None  2021-01-03 15:25:29
# 81   2021-01-05 20:38:20                 None  2021-01-05 20:38:20
# 141  2021-01-07 16:50:49                 None  2021-01-07 16:50:49
# 144  2021-01-07 05:08:16                 None  2021-01-07 17:08:17
# 175  2021-01-08 22:19:03                 None  2021-01-08 22:19:04
# 179  2021-01-08 22:19:41                 None  2021-01-08 22:19:41
# 282  2021-01-14 23:32:58                 None  2021-01-14 23:32:58
# 396  2021-01-21 20:58:40  2021-01-21 20:59:06  2021-01-21 20:59:15
# 424  2021-01-22 16:36:38  2021-01-22 16:37:01  2021-01-22 16:37:13
# 544  2021-01-28 21:24:25                 None  2021-01-28 21:24:25
# 559  2021-01-29 18:56:20                 None  2021-01-29 18:56:20
# 642  2021-02-01 16:48:13                 None  2021-02-01 16:48:13
# 656  2021-02-01 16:41:29                 None  2021-02-01 16:41:30
# 681  2021-02-02 00:28:02                 None  2021-02-02 00:28:03
# 727  2021-02-03 23:30:30                 None  2021-02-03 23:30:31
#
#        pointsAwardedDate  pointsEarned         purchaseDate  \
# 15                  None           NaN                 None
# 81                  None           NaN                 None
# 141                 None           NaN                 None
# 144                 None           NaN                 None
# 175                 None           NaN                 None
# 179                 None           NaN                 None
# 282                 None           NaN                 None
# 396  2021-01-21 20:59:06         250.0  2021-01-21 00:00:00
# 424  2021-01-22 16:37:01         500.0  2021-01-22 00:00:00
# 544                 None           NaN                 None
# 559                 None           NaN                 None
# 642                 None           NaN                 None
# 656                 None           NaN                 None
# 681                 None           NaN                 None
# 727                 None           NaN  2019-01-03 00:00:00
#
#      purchasedItemCount                             rewardsReceiptItemList  \
# 15                  0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 81                  0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 141                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 144                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 175                 0.0                                                NaN
# 179                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 282                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 396                 0.0                                                NaN
# 424                 0.0                                                NaN
# 544                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 559                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 642                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 656                 0.0                                                NaN
# 681                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 727                 0.0                                                NaN
#
#     rewardsReceiptStatus  totalSpent                    userId
# 15               FLAGGED         0.0  5ff1e1e9b6a9d73a3a9f10f6
# 81               FLAGGED         0.0  5ff4ce3cc1e2d0121a9b2fba
# 141              FLAGGED         0.0  5ff73be9eb7c7d31ca8a45bc
# 144              FLAGGED         0.0  5ff7946004929111f6e90ceb
# 175             REJECTED         0.0  5ff8da28b3348b11c9337ac6
# 179              FLAGGED         0.0  5ff8da7db3348b11c9337b6a
# 282              FLAGGED         0.0  6000d4aafb296c121a81b27e
# 396             FINISHED         0.0  6009e60450b3311194385009
# 424             FINISHED         0.0  600afb2a7d983a124e9aded0
# 544              FLAGGED         0.0  60132b8873c60b3ca7f3bae8
# 559              FLAGGED         0.0  60145a5467804a1228b20ded
# 642              FLAGGED         0.0  601830cdc8b50e11d8454a6f
# 656             REJECTED         0.0  60182f1dc8b50e11d84548c4
# 681              FLAGGED         0.0  60189c92c8b50e11d8454f5d
# 727             REJECTED         0.0  5a43c08fe4b014fd6b6a0612

# %% [markdown]
# #### Quality issues in the receipts table: for the receipts whose count of purchased items is zero still show points earned;
# #### there are more than 50% of missing values in some of the columns.
